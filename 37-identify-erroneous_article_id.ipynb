# %% [markdown]
# ## Load error_id file

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import random
import itertools
from itertools import product
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
import pmdarima as pm
from pmdarima.arima import auto_arima
import warnings

# %%
# %cd /data/p_dsi/teams2023/team7
# Out:
# /gpfs52/data/p_dsi/teams2023/team7

# %%
with open("dataframes_units_per_article_monthly.json") as json_file:
    data = json.load(json_file)

# %%
revert_dict = {}
for k in data.keys():
    temp = pd.DataFrame.from_dict(data[k])
    temp["DATE"] = pd.to_datetime(temp["DATE"])
    temp = temp.set_index("DATE")
    revert_dict.update({f"{k}": temp})

# %%
#revert_dict

# %%
with open("error_msg.json") as json_file:
    error_msg = json.load(json_file)

error_msg
# Out:
# {'1408': 'zero-size array to reduction operation maximum which has no identity',
#  '15454': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '15539': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '15046': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '14876': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '14995': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '15352': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '1814': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '15556': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '15369': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '15641': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '15658': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '15386': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '1427': 'zero-size array to reduction operation maximum which has no identity',
#  '1400': 'zero-size array to reduction operation maximum which has no identity',
#  '3561': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '15012': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '1411': 'zero-size array to reduction operation maximum which has no identity',
#  '1421': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '4042': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '3051': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '4012': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '4070': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '184': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '181': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '1435': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '3065': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '4022': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '3024': 'zero-size array to reduction operation maximum which has no identity',
#  '182': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '6258': 'zero-size array to reduction operation maximum which has no identity',
#  '4058': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '1404': 'zero-size array to reduction operation maximum which has no identity',
#  '2360': "Input contains NaN, infinity or a value too large for dtype('float64').",
#  '6251': 'There are no more samples after a first-order seasonal differencing. See http://alkaline-ml.com/pmdarima/seasonal-differencing-issues.html for a more in-depth explanation and potential work-arounds.',
#  '6252': 'zero-size array to reduction operation maximum which has no identity',
#  '4020': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '4034': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '189': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '6254': 'zero-size array to reduction operation maximum which has no identity',
#  '4046': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '3036': 'zero-size array to reduction operation maximum which has no identity',
#  '3816': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '4040': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '6253': 'There are no more samples after a first-order seasonal differencing. See http://alkaline-ml.com/pmdarima/seasonal-differencing-issues.html for a more in-depth explanation and potential work-arounds.',
#  '14808': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '4054': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '4028': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '6505': "Input contains NaN, infinity or a value too large for dtype('float64').",
#  '4915': 'There are no more samples after a first-order seasonal differencing. See http://alkaline-ml.com/pmdarima/seasonal-differencing-issues.html for a more in-depth explanation and potential work-arounds.',
#  '3068': 'zero-size array to reduction operation maximum which has no identity',
#  '4002': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '3019': 'zero-size array to reduction operation maximum which has no identity',
#  '6699': 'There are no more samples after a first-order seasonal differencing. See http://alkaline-ml.com/pmdarima/seasonal-differencing-issues.html for a more in-depth explanation and potential work-arounds.',
#  '3767': 'zero-size array to reduction operation maximum which has no identity',
#  '122': 'There are no more samples after a first-order seasonal differencing. See http://alkaline-ml.com/pmdarima/seasonal-differencing-issues.html for a more in-depth explanation and potential work-arounds.',
#  '113': 'There are no more samples after a first-order seasonal differencing. See http://alkaline-ml.com/pmdarima/seasonal-differencing-issues.html for a more in-depth explanation and potential work-arounds.',
#  '12394': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '185': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '6249': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '1414': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '1416': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '1402': 'zero-size array to reduction operation maximum which has no identity',
#  '6255': 'zero-size array to reduction operation maximum which has no identity',
#  '3034': 'zero-size array to reduction operation maximum which has no identity',
#  '1432': 'zero-size array to reduction operation maximum which has no identity',
#  '6256': 'zero-size array to reduction operation maximum which has no identity',
#  '4068': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '4062': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '4032': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '4030': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '4044': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '3351': 'There are no more samples after a first-order seasonal differencing. See http://alkaline-ml.com/pmdarima/seasonal-differencing-issues.html for a more in-depth explanation and potential work-arounds.',
#  '15216': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '4050': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '4014': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '118': 'There are no more samples after a first-order seasonal differencing. See http://alkaline-ml.com/pmdarima/seasonal-differencing-issues.html for a more in-depth explanation and potential work-arounds.',
#  '7788': 'There are no more samples after a first-order seasonal differencing. See http://alkaline-ml.com/pmdarima/seasonal-differencing-issues.html for a more in-depth explanation and potential work-arounds.',
#  '3040': 'zero-size array to reduction operation maximum which has no identity',
#  '3812': 'zero-size array to reduction operation maximum which has no identity',
#  '4018': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '187': 'shapes (4,2) and (1,) not aligned: 2 (dim 1) != 1 (dim 0)',
#  '3030': 'zero-size array to reduction operation maximum which has no identity',
#  '4263': 'There are no more samples after a first-order seasonal differencing. See http://alkaline-ml.com/pmdarima/seasonal-differencing-issues.html for a more in-depth explanation and potential work-arounds.',
#  '3058': 'zero-size array to reduction operation maximum which has no identity',
#  '6128': 'zero-size array to reduction operation maximum which has no identity',
#  '2928': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test.",
#  '33': 'There are no more samples after a first-order seasonal differencing. See http://alkaline-ml.com/pmdarima/seasonal-differencing-issues.html for a more in-depth explanation and potential work-arounds.',
#  '3042': 'zero-size array to reduction operation maximum which has no identity',
#  '12275': "All lag values up to 'maxlag' produced singular matrices. Consider using a longer series, a different lag term or a different test."}

# %%
error_msg.keys()
# Out:
# dict_keys(['1408', '15454', '15539', '15046', '14876', '14995', '15352', '1814', '15556', '15369', '15641', '15658', '15386', '1427', '1400', '3561', '15012', '1411', '1421', '4042', '3051', '4012', '4070', '184', '181', '1435', '3065', '4022', '3024', '182', '6258', '4058', '1404', '2360', '6251', '6252', '4020', '4034', '189', '6254', '4046', '3036', '3816', '4040', '6253', '14808', '4054', '4028', '6505', '4915', '3068', '4002', '3019', '6699', '3767', '122', '113', '12394', '185', '6249', '1414', '1416', '1402', '6255', '3034', '1432', '6256', '4068', '4062', '4032', '4030', '4044', '3351', '15216', '4050', '4014', '118', '7788', '3040', '3812', '4018', '187', '3030', '4263', '3058', '6128', '2928', '33', '3042', '12275'])

# %%
error_data = {}
for article_id in error_msg.keys():
    data = revert_dict[article_id]
    #print(data)
    error_data[article_id] = data
    plt.plot(data, label = article_id)
    plt.legend(loc = "upper left")
    plt.show()
