# %% [markdown]
# # 1. Import packages
# ----------

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %cd /data/p_dsi/teams2023/team7/
# Out:
# /gpfs52/data/p_dsi/teams2023/team7

# %% [markdown]
# # 2. Extract paths that are needed
# ------

# %% [markdown]
# ## 2.1 Remove yearly tire sales

# %%
paths = glob.glob('tire_sales_201*.csv')
paths.remove('tire_sales_2017.csv')
paths.remove('tire_sales_2016.csv')
paths.remove('tire_sales_2015.csv')
paths.remove('tire_sales_2018.csv')
len(paths)
# Out:
# 43

# %% [markdown]
# ## 2.2 Sort the paths by time

# %%
import os
from datetime import datetime

# Define a function to extract the datetime from a path string
def extract_datetime(path):
    filename = os.path.basename(path)
    datetime_str = filename.split('_')[2].split('.')[0]
    return datetime.strptime(datetime_str, '%Y%m%d')

# Sort the list of paths by datetime using the extract_datetime function as the key
path_list = sorted(paths, key=extract_datetime)

# Print the sorted list of paths
print(path_list)
# Out:
# ['tire_sales_20150430.csv', 'tire_sales_20150531.csv', 'tire_sales_20150630.csv', 'tire_sales_20150731.csv', 'tire_sales_20150831.csv', 'tire_sales_20150930.csv', 'tire_sales_20151031.csv', 'tire_sales_20151130.csv', 'tire_sales_20151231.csv', 'tire_sales_20160131.csv', 'tire_sales_20160229.csv', 'tire_sales_20160331.csv', 'tire_sales_20160430.csv', 'tire_sales_20160531.csv', 'tire_sales_20160630.csv', 'tire_sales_20160731.csv', 'tire_sales_20160831.csv', 'tire_sales_20160930.csv', 'tire_sales_20161031.csv', 'tire_sales_20161130.csv', 'tire_sales_20161231.csv', 'tire_sales_20170131.csv', 'tire_sales_20170228.csv', 'tire_sales_20170331.csv', 'tire_sales_20170430.csv', 'tire_sales_20170531.csv', 'tire_sales_20170630.csv', 'tire_sales_20170731.csv', 'tire_sales_20170831.csv', 'tire_sales_20170930.csv', 'tire_sales_20171031.csv', 'tire_sales_20171130.csv', 'tire_sales_20171231.csv', 'tire_sales_20180131.csv', 'tire_sales_20180228.csv', 'tire_sales_20180331.csv', 'tire_sales_20180430.csv'
# ...

# %% [markdown]
# # 3. Read data and make visulization plots
# --------

# %% [markdown]
# ## 3.1 Read individual data

# %%
inv = pd.read_csv('/data/p_dsi/teams2023/bridgestone_data/data/individual.csv')

# %% [markdown]
# ## 3.2 Join individual data to every monthly tire sales data and visulize them

# %% [markdown]
# ### 3.2.1 Visualize "EMAIL_OPTIN_IND"

# %%
for path in path_list:
    month = re.findall(r'\d+', path)
    tire_sales = pd.read_csv(path)
    merge_df = pd.merge(tire_sales, inv, left_on='INDIV_ID', right_on='MZB_INDIV_ID',how='left')
    email_counts = merge_df['EMAIL_OPTIN_IND'].value_counts()
    email_counts.plot(kind='bar')
    plt.title(month)
    plt.xlabel('EMAIL_OPTIN_IND')
    plt.ylabel('Count')
    plt.show()
    print(email_counts)
# Out:
# Y    281541
# N     89161
# U      1797
# Name: EMAIL_OPTIN_IND, dtype: int64
# Y    304006
# N     95503
# U      2144
# Name: EMAIL_OPTIN_IND, dtype: int64
# Y    302004
# N     95313
# U      2161
# Name: EMAIL_OPTIN_IND, dtype: int64
# Y    307397
# N     89684
# U      2083
# Name: EMAIL_OPTIN_IND, dtype: int64
# Y    308376
# N     84821
# U      2825
# Name: EMAIL_OPTIN_IND, dtype: int64
# Y    310227
# N     84463
# U      2716
# Name: EMAIL_OPTIN_IND, dtype: int64
# Y    312869
# N     92299
# U      2983
# Name: EMAIL_OPTIN_IND, dtype: int64
# Y    359004
# N     98379
# U      3441
# Name: EMAIL_OPTIN_IND, dtype: int64
# Y    282735
# N     76393
# U      2733
# Name: EMAIL_OPTIN_IND, dtype: int64
# Y    284995
# N     73977
# U      2724
# Name: EMAIL_OPTIN_IND, dtype: int64
# Y    280223
# N     68903
# U      2575
# Name: EMAIL_OPTIN_IND, dtype: int64
# Y    302022
# N     74651
# U      2820
# Name: EMAIL_OPTIN_IND, dtype: int64
# Y    294944
# N     72160
# ...

# %% [markdown]
# ### 3.2.2 Visualize "AH1_RES_BUS_INDC"

# %%
for path in path_list:
    month = re.findall(r'\d+', path)
    tire_sales = pd.read_csv(path)
    merge_df = pd.merge(tire_sales, inv, left_on='INDIV_ID', right_on='MZB_INDIV_ID',how='left')
    AH1_counts = merge_df['AH1_RES_BUS_INDC'].value_counts()
    AH1_counts.plot(kind='bar')
    plt.title(month)
    plt.xlabel('AH1_RES_BUS_INDC')
    plt.ylabel('Count')
    plt.show()
    print(AH1_counts)
# Out:
# R    327356
# U     18403
# B     11151
# Name: AH1_RES_BUS_INDC, dtype: int64
# R    353627
# U     20019
# B     11822
# Name: AH1_RES_BUS_INDC, dtype: int64
# R    352293
# U     19341
# B     11857
# Name: AH1_RES_BUS_INDC, dtype: int64
# R    349701
# U     20507
# B     11934
# Name: AH1_RES_BUS_INDC, dtype: int64
# R    347502
# U     20495
# B     12024
# Name: AH1_RES_BUS_INDC, dtype: int64
# R    347836
# U     20915
# B     12282
# Name: AH1_RES_BUS_INDC, dtype: int64
# R    357233
# U     21729
# B     12669
# Name: AH1_RES_BUS_INDC, dtype: int64
# R    406966
# U     23600
# B     12475
# Name: AH1_RES_BUS_INDC, dtype: int64
# R    316960
# U     19530
# B     11283
# Name: AH1_RES_BUS_INDC, dtype: int64
# R    318410
# U     18524
# B     10641
# Name: AH1_RES_BUS_INDC, dtype: int64
# R    308471
# U     18743
# B     10377
# Name: AH1_RES_BUS_INDC, dtype: int64
# R    333155
# U     20075
# B     11009
# Name: AH1_RES_BUS_INDC, dtype: int64
# R    323863
# U     19254
# ...

# %% [markdown]
# ### 3.2.3 Visualize "SUPP1_BUS_PANDER"

# %%
for path in path_list:
    month = re.findall(r'\d+', path)
    tire_sales = pd.read_csv(path)
    merge_df = pd.merge(tire_sales, inv, left_on='INDIV_ID', right_on='MZB_INDIV_ID',how='left')
    SUPP_counts = merge_df['SUPP1_BUS_PANDER'].value_counts()
    SUPP_counts.plot(kind='bar')
    plt.title(month)
    plt.xlabel('SUPP1_BUS_PANDER')
    plt.ylabel('Count')
    plt.show()
    print(SUPP_counts)
# Out:
# N    355627
# Y      1283
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    384030
# Y      1438
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    382202
# Y      1289
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    380860
# Y      1282
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    378714
# Y      1307
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    379669
# Y      1364
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    390089
# Y      1542
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    441444
# Y      1597
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    346517
# Y      1256
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    346242
# Y      1333
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    336381
# Y      1210
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    362944
# Y      1295
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    352817
# Y      1226
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    365200
# Y      1288
# Name: SUPP1_BUS_PANDER, dtype: int64
# N    389577
# Y      1586
# ...

# %% [markdown]
# # 4. Findings
# ### We don't find any differences in individual data on different timeframes.
