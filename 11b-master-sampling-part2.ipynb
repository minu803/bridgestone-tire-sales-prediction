# %% [markdown]
# # 1. Import packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import glob

# %% [markdown]
# # 2. Load product data and extract ARTICLE_ID for tire sales

# %% [markdown]
# ## 2.1 Load product data

# %%
product = pd.read_csv('/data/p_dsi/teams2023/bridgestone_data/data/product.csv', sep = '|')

# %%
product.info()
product.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56842 entries, 0 to 56841
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ARTICLE_ID       56842 non-null  int64
#  1   PROD_GROUP_CODE  56818 non-null  float64
#  2   PROD_GROUP_DESC  56818 non-null  object
#  3   CATEGORY_CODE    56818 non-null  float64
#  4   CATEGORY_DESC    56818 non-null  object
#  5   SEGMENT_CODE     56818 non-null  float64
#  6   SEGMENT_DESC     56818 non-null  object
#  7   CLASS_CODE       56818 non-null  float64
#  8   CLASS_DESC       56818 non-null  object
#  9   DISCOUNT_FLAG    56818 non-null  object
#  10  CROSS_SECTION    35670 non-null  object
#  11  ASPECT_RATIO     35665 non-null  object
#  12  RIM_SIZE         35504 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 5.6+ MB
#        ARTICLE_ID  PROD_GROUP_CODE PROD_GROUP_DESC  CATEGORY_CODE  \
# 43151     7005219              4.0        Services           83.0
# 34638     7083544              5.0           Tires           26.0
# 27858      224133              5.0           Tires           44.0
# 6839        11982              5.0           Tires           26.0
# 27008     7096258              5.0           Tires           26.0
# 8850         1183              5.0           Tires           26.0
# 9355      7082375              5.0           Tires           26.0
# 21910     7086679              5.0           Tires           44.0
# 10674     7095323              5.0           Tires           26.0
# 1269         4321              5.0           Tires           26.0
#
#                         CATEGORY_DESC  SEGMENT_CODE  \
# 43151  Steering/Suspension/Drivetrain          96.0
# 34638                 Passenger Tires          29.0
# 27858               Light Truck Tires          47.0
# 6839                  Passenger Tires          29.0
# 27008                 Passenger Tires          30.0
# 8850                  Passenger Tires        1135.0
# 9355                  Passenger Tires        1135.0
# 21910               Light Truck Tires          46.0
# 10674                 Passenger Tires          30.0
# 1269                  Passenger Tires          29.0
#
#                      SEGMENT_DESC  CLASS_CODE  \
# 43151                  Alignments       190.0
# 34638           Performance Tires     58530.0
# 27858            Commercial Tires        51.0
# 6839            Performance Tires     58530.0
# 27008  P Metric Light Truck Tires        42.0
# 8850                Snow Tires-PS      1136.0
# 9355                Snow Tires-PS      1136.0
# 21910          Recreational Tires        49.0
# 10674  P Metric Light Truck Tires        41.0
# 1269            Performance Tires        39.0
#
#                               CLASS_DESC DISCOUNT_FLAG CROSS_SECTION  \
# 43151                 Lifetime Alignment             Y           NaN
# 34638  Ultra High Performance All Season             N           NaN
# 27858                      Highway Tires             N           225
# 6839   Ultra High Performance All Season             N           235
# 27008                  All Terrain Tires             N           245
# 8850                          Snow Tires             N           215
# 9355                          Snow Tires             N           175
# 21910                  All Terrain Tires             N           275
# 10674                      Highway Tires             N           225
# 1269                 Touring H/V/Z Tires             N           205
#
#       ASPECT_RATIO RIM_SIZE
# 43151          NaN      NaN
# 34638          NaN      NaN
# 27858           75       17
# 6839            40       18
# 27008           70       16
# 8850            70       15
# 9355            65       14
# 21910           55       20
# 10674           65       17
# 1269            65       16

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56842 entries, 0 to 56841
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ARTICLE_ID       56842 non-null  int64
#  1   PROD_GROUP_CODE  56818 non-null  float64
#  2   PROD_GROUP_DESC  56818 non-null  object
#  3   CATEGORY_CODE    56818 non-null  float64
#  4   CATEGORY_DESC    56818 non-null  object
#  5   SEGMENT_CODE     56818 non-null  float64
#  6   SEGMENT_DESC     56818 non-null  object
#  7   CLASS_CODE       56818 non-null  float64
#  8   CLASS_DESC       56818 non-null  object
#  9   DISCOUNT_FLAG    56818 non-null  object
#  10  CROSS_SECTION    35670 non-null  object
#  11  ASPECT_RATIO     35665 non-null  object
#  12  RIM_SIZE         35504 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 5.6+ MB

# %% [markdown]
# ## 2.2 Select tire sales data

# %%
tire_sales = product[(product["CATEGORY_CODE"] == 44.0) | (product["CATEGORY_CODE"] == 26.0)]
tire_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32563 entries, 0 to 56822
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ARTICLE_ID       32563 non-null  int64
#  1   PROD_GROUP_CODE  32563 non-null  float64
#  2   PROD_GROUP_DESC  32563 non-null  object
#  3   CATEGORY_CODE    32563 non-null  float64
#  4   CATEGORY_DESC    32563 non-null  object
#  5   SEGMENT_CODE     32563 non-null  float64
#  6   SEGMENT_DESC     32563 non-null  object
#  7   CLASS_CODE       32563 non-null  float64
#  8   CLASS_DESC       32563 non-null  object
#  9   DISCOUNT_FLAG    32563 non-null  object
#  10  CROSS_SECTION    31964 non-null  object
#  11  ASPECT_RATIO     31959 non-null  object
#  12  RIM_SIZE         31963 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 3.5+ MB

# %% [markdown]
# ## 2.3 Extract Article_ID

# %%
# Extract the ARTICLE_ID from tire_sales
ARTICLE_ID_list = tire_sales["ARTICLE_ID"].unique().tolist()

# %%
#print(ARTICLE_ID_list)
len(ARTICLE_ID_list)
# Out:
# 32563

# %% [markdown]
# # 3. Load sales data and subset all tire sales

# %%
# sample testing with one month in 2017
sales_2017_oct = pd.read_csv('/data/p_dsi/teams2023/bridgestone_data/data/sales_20171031.csv', sep = '|')
sales_2017_oct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15800806 entries, 0 to 15800805
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   STORE_ID    int64
#  1   TRAN_ID     int64
#  2   DATE        object
#  3   ARTICLE_ID  int64
#  4   INDIV_ID    float64
#  5   VEHICLE_ID  int64
#  6   UNITS       float64
#  7   SALES       float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 964.4+ MB

# %%
# example of getting ARTICLE_ID and UNITS 
master_small = sales_2017_oct[["ARTICLE_ID", "UNITS"]]
tire_sales_2017 = master_small[master_small['ARTICLE_ID'].isin(ARTICLE_ID_list)]
tire_sales_2017
df = tire_sales_2017.groupby(by=["ARTICLE_ID"]).sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3536 entries, 9 to 7099853
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   UNITS   3536 non-null   float64
# dtypes: float64(1)
# memory usage: 55.2 KB

# %%
# Create a concatenated data frame with ARTICLE_ID and UNITS in Nov, Dec 2017
csv_files = ['/data/p_dsi/teams2023/bridgestone_data/data/sales_20171130.csv',
             '/data/p_dsi/teams2023/bridgestone_data/data/sales_20171231.csv']

# create a new data frame
master_tire_sales_2017 = pd.DataFrame()
for file in csv_files:
    sales_2017 = pd.read_csv(file, sep = "|")
    sales_small = sales_2017[["ARTICLE_ID", "UNITS"]]
    tire_sales_2017 = sales_small[sales_small['ARTICLE_ID'].isin(ARTICLE_ID_list)]
    df = tire_sales_2017.groupby(by=["ARTICLE_ID"]).sum()
    master_tire_sales_2017 = pd.concat([master_tire_sales_2017, df])

master_tire_sales_2017.info()
master_tire_sales_2017.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7089 entries, 9 to 7099819
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   UNITS   7089 non-null   float64
# dtypes: float64(1)
# memory usage: 110.8 KB
#              UNITS
# ARTICLE_ID
# 7092043        0.0
# 7094247        0.0
# 7092011        0.0
# 7097106        0.0
# 145954        10.0
# 843            9.0
# 114589      4735.0
# 2459         110.0
# 71171         16.0
# 817         1275.0

# %%
# Sum by the article_id again to get the total result
master_tire_sales_2017 = master_tire_sales_2017.groupby(by=["ARTICLE_ID"]).sum()
master_tire_sales_2017.info()
master_tire_sales_2017.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4146 entries, 9 to 7099982
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   UNITS   4146 non-null   float64
# dtypes: float64(1)
# memory usage: 64.8 KB
#             UNITS
# ARTICLE_ID
# 2842        116.0
# 5053          8.0
# 1342         28.0
# 6444        695.0
# 7012498       0.0
# 7012468       0.0
# 7092571       0.0
# 7099574       0.0
# 7090810      14.0
# 7089185       0.0

# %%
# save as csv file
master_tire_sales_2017.to_csv("/data/p_dsi/teams2023/team7/tire_sales_article_id_and_total_units_Nov_Dec_2017.csv")

# %%
# Create a concatenated data frame with ARTICLE_ID and UNITS from Jan - Oct in 2018
csv_files = glob.glob('/data/p_dsi/teams2023/bridgestone_data/data/*sales_2018*.csv')

master_tire_sales_2018 = pd.DataFrame()
for file in csv_files:
    sales_2018 = pd.read_csv(file, sep = "|")
    sales_small = sales_2018[["ARTICLE_ID", "UNITS"]]
    tire_sales_2018 = sales_small[sales_small['ARTICLE_ID'].isin(ARTICLE_ID_list)]
    df = tire_sales_2018.groupby(by=["ARTICLE_ID"]).sum()
    master_tire_sales_2018 = pd.concat([master_tire_sales_2018, df])
    
master_tire_sales_2018.info()
master_tire_sales_2018.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39162 entries, 9 to 7099847
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   UNITS   39162 non-null  float64
# dtypes: float64(1)
# memory usage: 611.9 KB
#              UNITS
# ARTICLE_ID
# 1405        1328.0
# 142486         4.0
# 5015           8.0
# 3459          30.0
# 7092836        0.0
# 7091165        2.0
# 7084436        1.0
# 112569         1.0
# 148300        66.0
# 7086373        1.0

# %%
# Sum by the article_id again to get the total result
master_tire_sales_2018 = master_tire_sales_2018.groupby(by=["ARTICLE_ID"]).sum()
master_tire_sales_2018.info()
master_tire_sales_2018.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7856 entries, 9 to 7099854
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   UNITS   7856 non-null   float64
# dtypes: float64(1)
# memory usage: 122.8 KB
#              UNITS
# ARTICLE_ID
# 7091280       39.0
# 5126        1458.0
# 57809         34.0
# 7086840        5.0
# 12071       1873.0
# 579          111.0
# 79297          2.0
# 7090995        0.0
# 7082430        1.0
# 7087805        2.0

# %%
# save as csv file
master_tire_sales_2018.to_csv("/data/p_dsi/teams2023/team7/tire_sales_article_id_and_total_units_2018.csv")

# %%
# Now load two files from 2017 and 2018 and bind them together for the last time
unit_tire_sales_year = pd.concat([master_tire_sales_2017, master_tire_sales_2018])
unit_tire_sales_year = unit_tire_sales_year.groupby(by=["ARTICLE_ID"]).sum()

# filter by the sales greater than 5,000
unit_tire_sales_year = unit_tire_sales_year.loc[unit_tire_sales_year['UNITS'] > 5000]
unit_tire_sales_year.info()
unit_tire_sales_year.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 33 to 7099817
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   UNITS   435 non-null    float64
# dtypes: float64(1)
# memory usage: 6.8 KB
#               UNITS
# ARTICLE_ID
# 452          8328.0
# 122          6021.0
# 1734        27110.0
# 2815        11212.0
# 4014        23720.0
# 6478        18178.0
# 3421        14998.0
# 15165        6335.0
# 3503        14997.0
# 3843        18559.0

# %%
#save the final result in csv file
unit_tire_sales_year.to_csv("/data/p_dsi/teams2023/team7/tire_sales_article_id_and_total_units_last_12_months.csv")

# %%
# Sanity check
unit_tire_sales_last_12_months = pd.read_csv("/data/p_dsi/teams2023/team7/tire_sales_article_id_and_total_units_last_12_months.csv", sep = ',')

# Extract the ARTICLE_ID from tire_sales
ARTICLE_ID_list = unit_tire_sales_last_12_months["ARTICLE_ID"].tolist()

#print(ARTICLE_ID_list)
len(ARTICLE_ID_list)
# Out:
# 435

# %%
master_sample = pd.read_csv("/data/p_dsi/teams2023/team7/master_sample.csv")

# %%
master_sample.info()
master_sample.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 34 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0.2      100000 non-null  int64
#  1   Unnamed: 0.1      100000 non-null  int64
#  2   Unnamed: 0        100000 non-null  int64
#  3   STORE_ID          100000 non-null  int64
#  4   TRAN_ID           100000 non-null  int64
#  5   DATE              100000 non-null  object
#  6   ARTICLE_ID        100000 non-null  int64
#  7   INDIV_ID          99822 non-null   float64
#  8   VEHICLE_ID        100000 non-null  int64
#  9   UNITS             100000 non-null  float64
#  10  SALES             100000 non-null  float64
#  11  MZB_INDIV_ID      53265 non-null   float64
#  12  EMAIL_OPTIN_IND   53265 non-null   object
#  13  AH1_RES_BUS_INDC  51187 non-null   object
#  14  SUPP1_BUS_PANDER  51187 non-null   object
#  15  PROD_GROUP_CODE   100000 non-null  float64
#  16  PROD_GROUP_DESC   100000 non-null  object
#  17  CATEGORY_CODE     100000 non-null  float64
#  18  CATEGORY_DESC     100000 non-null  object
#  19  SEGMENT_CODE      100000 non-null  float64
#  20  SEGMENT_DESC      100000 non-null  object
#  21  CLASS_CODE        100000 non-null  float64
#  22  CLASS_DESC        100000 non-null  object
#  23  DISCOUNT_FLAG     100000 non-null  object
#  24  CROSS_SECTION     100000 non-null  object
#  25  ASPECT_RATIO      100000 non-null  object
#  26  RIM_SIZE          100000 non-null  object
#  27  STATE_CODE        100000 non-null  object
#  28  ZIP_CODE          100000 non-null  int64
#  29  MSA               78705 non-null   object
#  30  MAKE              93165 non-null   object
#  31  MODEL             93165 non-null   object
#  32  SUB_MODEL         83030 non-null   object
#  33  MODEL_YEAR        93165 non-null   float64
# dtypes: float64(9), int64(8), object(17)
# memory usage: 25.9+ MB
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  STORE_ID    TRAN_ID  \
# 77698         77698        184198     4728837     16357  992561910
# 3181           3181       1127949     8617660     27499  991230250
# 2526           2526       1621763     6075735    240187  992613130
# 9108           9108       1370917      244791    352044  990782810
# 70341         70341       1345903      117106      3328  991996290
# 25432         25432       5001714     7125326    353227  990612250
# 94780         94780       1890282    13763863      4227  992257770
# 35809         35809       7749235     2337763      4340  991698670
# 33747         33747       3882991    11503188    679259  992554950
# 11675         11675       1245923    12090050    121983  990918230
#
#              DATE  ARTICLE_ID     INDIV_ID  VEHICLE_ID  UNITS  ...  \
# 77698  2018-07-23     7089671  285492885.0   915800928    0.0  ...
# 3181   2017-07-27     7090002  288465538.0   960352874    0.0  ...
# 2526   2017-05-11     7012601  261973659.0   936512026    0.0  ...
# 9108   2017-05-15        3431  258390732.0   936409750    1.0  ...
# 70341  2015-11-27      117751  284811922.0   897489268    0.0  ...
# 25432  2017-06-02       85893  253344155.0   929731040    1.0  ...
# 94780  2018-05-30     7089226  542103504.0           1    0.0  ...
# 35809  2016-02-01      136893  271349457.0   692907204    1.0  ...
# 33747  2016-10-01      122817  293629443.0   937982930    1.0  ...
# 11675  2017-07-02       47150  285369059.0   930859511    4.0  ...
#
#        CROSS_SECTION  ASPECT_RATIO RIM_SIZE STATE_CODE ZIP_CODE         MSA  \
# 77698           NONE          NONE     NONE         VA    22306  WASHINGTON
# 3181            NONE          NONE     NONE         OH    43223  COLUMBUS,O
# 2526            NONE          NONE     NONE         OK    73110         NaN
# 9108             215            60       16         CA    95843  SACRAMENTO
# 70341            205            55       16         AL    35124  BIRMINGHAM
# 25432            195            65       15         NC    28079  CHARLOTTE,
# 94780           NONE          NONE     NONE         FL    34471    OCALA,FL
# 35809            225            55       16         FL    33020  FT.LAUDERD
# 33747            225            65       17         TX    77092  HOUSTON,TX
# 11675            205            70       15         FL    34474         NaN
#
#             MAKE            MODEL    SUB_MODEL  MODEL_YEAR
# 77698      MAZDA              3 S  S Hatchback      2007.0
# 3181    CADILLAC  ATS PERFORMANCE  Performance      2013.0
# 2526      TOYOTA        COROLLA S            S      2011.0
# 9108      NISSAN         ALTIMA S        S 2.5      2014.0
# 70341  CHEVROLET        COBALT LS           LS      2008.0
# 25432      HONDA        ACCORD DX           DX      2000.0
# 94780        NaN              NaN          NaN         NaN
# 35809       FORD     MUSTANG BASE         Base      2003.0
# 33747  CHEVROLET       EQUINOX LT           LT      2012.0
# 11675     TOYOTA        SIENNA LE           LE      1998.0
#
# [10 rows x 34 columns]

# %%
master_sample_selected_article_ids = master_sample[master_sample['ARTICLE_ID'].isin(ARTICLE_ID_list)]

# %%
master_sample_selected_article_ids.info()
master_sample_selected_article_ids.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46012 entries, 0 to 99997
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0.2      46012 non-null  int64
#  1   Unnamed: 0.1      46012 non-null  int64
#  2   Unnamed: 0        46012 non-null  int64
#  3   STORE_ID          46012 non-null  int64
#  4   TRAN_ID           46012 non-null  int64
#  5   DATE              46012 non-null  object
#  6   ARTICLE_ID        46012 non-null  int64
#  7   INDIV_ID          45910 non-null  float64
#  8   VEHICLE_ID        46012 non-null  int64
#  9   UNITS             46012 non-null  float64
#  10  SALES             46012 non-null  float64
#  11  MZB_INDIV_ID      23832 non-null  float64
#  12  EMAIL_OPTIN_IND   23832 non-null  object
#  13  AH1_RES_BUS_INDC  22878 non-null  object
#  14  SUPP1_BUS_PANDER  22878 non-null  object
#  15  PROD_GROUP_CODE   46012 non-null  float64
#  16  PROD_GROUP_DESC   46012 non-null  object
#  17  CATEGORY_CODE     46012 non-null  float64
#  18  CATEGORY_DESC     46012 non-null  object
#  19  SEGMENT_CODE      46012 non-null  float64
#  20  SEGMENT_DESC      46012 non-null  object
#  21  CLASS_CODE        46012 non-null  float64
#  22  CLASS_DESC        46012 non-null  object
#  23  DISCOUNT_FLAG     46012 non-null  object
#  24  CROSS_SECTION     46012 non-null  object
#  25  ASPECT_RATIO      46012 non-null  object
#  26  RIM_SIZE          46012 non-null  object
#  27  STATE_CODE        46012 non-null  object
#  28  ZIP_CODE          46012 non-null  int64
#  29  MSA               35908 non-null  object
#  30  MAKE              42356 non-null  object
#  31  MODEL             42356 non-null  object
#  32  SUB_MODEL         37728 non-null  object
#  33  MODEL_YEAR        42356 non-null  float64
# dtypes: float64(9), int64(8), object(17)
# memory usage: 12.3+ MB
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  STORE_ID    TRAN_ID  \
# 68247         68247       5267708     8877289     12505  991664800
# 57562         57562       2161776      228629      4677  990914200
# 32840         32840       6930549    13683677     20745  992092240
# 9318           9318       7567924     3664740     26573  992586100
# 61514         61514       1176166    13113344    678635  992473280
# 72323         72323        147086     3391146     28460  991480160
# 25965         25965       4662980    15511974      1031  991875420
# 81345         81345       6184253     6592994    749144  990402490
# 35893         35893       1411923     1843051    635871  992062150
# 84476         84476       4830441     7682507     25046  991453110
#
#              DATE  ARTICLE_ID     INDIV_ID  VEHICLE_ID  UNITS  ...  \
# 68247  2015-12-20        3419  290508082.0   944688407    1.0  ...
# 57562  2015-04-09      122596  303886073.0   938258662    4.0  ...
# 32840  2016-11-22      122630  481720719.0   952780112    1.0  ...
# 9318   2017-11-03       92319  256352544.0   960922564    2.0  ...
# 61514  2015-05-14       97912  276120721.0   939086392    4.0  ...
# 72323  2015-07-20      136094  255494272.0   940702550    1.0  ...
# 25965  2017-10-11       15182  272834125.0   949900465    1.0  ...
# 81345  2018-03-25         832  271891112.0           1    4.0  ...
# 35893  2016-09-20      122613  256596139.0   940538195    1.0  ...
# 84476  2018-10-08       26869  288200115.0   457320314    2.0  ...
#
#        CROSS_SECTION  ASPECT_RATIO RIM_SIZE STATE_CODE ZIP_CODE         MSA  \
# 68247            225            55       17         WA    98901   YAKIMA,WA
# 57562            195            65       15         LA    70801  BATON ROUG
# 32840            225            60       16         MS    39402  NON-MET MS
# 9318             195            70       14         VA    23231  RICHMOND,V
# 61514            265            70       17         TX    79605  ABILENE,TX
# 72323            235            60       18         OR    97045  PORTLAND,O
# 25965            205            60       16         NJ     7042   NEWARK,NJ
# 81345            225            50       17         TX    77494  HOUSTON,TX
# 35893            205            65       15         FL    32726         NaN
# 84476            255            70       16         OK    73701     ENID,OK
#
#             MAKE              MODEL       SUB_MODEL  MODEL_YEAR
# 68247  CHEVROLET          IMPALA LT             NaN      2014.0
# 57562     TOYOTA         COROLLA LE              LE      2011.0
# 32840  CHEVROLET          IMPALA LS              LS      2008.0
# 9318   CHEVROLET      CAVALIER BASE            Base      2001.0
# 61514  CHEVROLET   SUBURBAN 1500 LS              LS      2013.0
# 72323      HONDA      PILOT TOURING         Touring      2012.0
# 25965      LEXUS         ES300 BASE            Base      2001.0
# 81345        NaN                NaN             NaN         NaN
# 35893   CHRYSLER         SEBRING LX  LX Convertible      2002.0
# 84476  CHEVROLET  SILVERADO 1500 LS          LS 4x2      2000.0
#
# [10 rows x 34 columns]
